# %%
# !python --version
# Out:
# Python 3.12.4

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('../images/cute_dog.jpeg')

# %%
cv2.imshow('test', img)

# %%
plt.imshow(img)

# %%
print(img.shape)
# Out:
# (554, 554, 3)

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
