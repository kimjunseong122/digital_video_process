# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# from google.colab import drive
# from google.colab.patches import cv2_imshow

# %%
# drive.mount('/content/drive')

# %%
img = cv2.imread('../images/my_dog_jelly.jpeg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %%
img = cv2.imread('../images/lena256.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# cv2.imshow('Lena', RGB_img)
plt.imshow(RGB_img)

# %%
Gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(Gray_img.shape)
plt.imshow(Gray_img, cmap='gray')
# Out:
# (256, 256)

# %%
# cv2_imshow(Gray_img)
cv2.imshow('Gray', Gray_img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# 2024-09-23 11:43:22.975 python[29503:1527776] +[IMKClient subclass]: chose IMKClient_Legacy
# 2024-09-23 11:43:22.975 python[29503:1527776] +[IMKInputSession subclass]: chose IMKInputSession_Legacy

# %%
mlmg = cv2.resize(Gray_img, (256*4, 256*4))
plt.imshow(mlmg, cmap='gray')

# %%
for h in range(100, 150):
    for w in range(100, 150):
        Gray_img[h, w] = 0

cv2.imshow('Gray', Gray_img)
cv2.waitKey()
cv2.destroyAllWindows()
