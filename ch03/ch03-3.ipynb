# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# from google.colab import drive
# from google.colab.patches import cv2_imshow

# %%
# drive.mount('/content/drive')

# %%
# img = cv2.imread('../images/abcdef.bmp')
img = cv2.imread('../images/lena256.jpg')

RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
print(gImg1.shape)
plt.imshow(gImg1, cmap='gray')

# cv2.imshow('Lena', RGB_img)
# cv2.waitKey()
# cv2.destroyAllWindows()
# Out:
# (256, 256)

# %%
# img = cv2.imread('../images/a.bmp')
img = cv2.imread('../images/circle.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg2 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
print(gImg2.shape)
plt.imshow(gImg2, cmap='gray')

# cv2.imshow('Lena', RGB_img)
# cv2.waitKey()
# cv2.destroyAllWindows()
# Out:
# (286, 322)

# %%
gBit = np.zeros((gImg1.shape[0], gImg1.shape[1]), dtype=np.ubyte)

# %%
for h in range(gImg1.shape[0]):
    for w in range(gImg1.shape[1]):
        # bitVal = gImg1[h, w] & gImg2[h, w]
        # bitVal = gImg1[h, w] | gImg2[h, w]
        bitVal = gImg1[h, w] ^ gImg2[h, w]
        gBit[h, w] = bitVal

plt.imshow(gBit, cmap='gray')
